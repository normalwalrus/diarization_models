# %%
# %pip install pyannote.metrics
# %pip install pyannote.core

# %%
from pyannote.metrics.diarization import DiarizationErrorRate
from pyannote.core import Annotation, Timeline, Segment

def read_rttm_file_into_annotation(rttm_path):

    speaker_segments = Annotation()
    
    with open(rttm_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if parts[0] == "SPEAKER": 
                speaker = parts[7]
                start_time = float(parts[3])
                duration = float(parts[4])
                end_time = start_time + duration

                speaker_segments[Segment(round(start_time, 2), round(end_time,2))] = speaker

    return speaker_segments

def compute_der(hyp_rttm_path, ref_rttm_path):
    """
    Compute Diarization Error Rate (DER) allowing overlap.
    
    :param reference: Ground truth diarization (pyannote Annotation)
    :param hypothesis: Predicted diarization (pyannote Annotation)
    :return: DER score
    """
    metric = DiarizationErrorRate(skip_overlap=False)
    hypothesis = read_rttm_file_into_annotation(hyp_rttm_path)
    reference = read_rttm_file_into_annotation(ref_rttm_path)

    der_score = metric(reference, hypothesis)
    return der_score

# %%
import simpleder

nemo_rttm_path = 'outputs/nemo_test.rttm'
pyannote_rttm_path = 'outputs/pyannote_test.rttm'
reverb_rttm_path = 'outputs/reverb_test.rttm'

reference_rttm_path = 'ami_dataset/IS1002c.Mix-Headset.rttm'

nemo_error = compute_der(nemo_rttm_path, reference_rttm_path)
pyannote_error = compute_der(pyannote_rttm_path, reference_rttm_path)
reverb_error = compute_der(reverb_rttm_path, reference_rttm_path)

print(f"Nemo's DER: {nemo_error}")
print(f"Pyannote's DER: {pyannote_error}")
print(f"Reverb's DER: {reverb_error}")
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyannote\metrics\utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# Nemo's DER: 0.2010746232204104
# Pyannote's DER: 0.12757080199863757
# Reverb's DER: 0.30597759166352895

# %%
import os

PATH_TO_PYANNOTE = 'outputs/pyannote_community_1/AMI/'

rttm_files_done = [f for f in os.listdir(PATH_TO_PYANNOTE) if f.endswith(".rttm")]

#PATH_TO_NEMO = 'outputs/nemo/'
#PATH_TO_REVERB = 'outputs/reverb/'

PATH_TO_REFERENCE = '/home/digitalhub/Desktop/data/diarization_benchmarks/ami_dataset/rttm/'

nemo_scores = []
pyannote_scores = []
reverb_scores = []

count = 0

for rttm_file in rttm_files_done:
    print(rttm_file)

    #nemo_rttm_path = PATH_TO_NEMO + rttm_file
    pyannote_rttm_path = PATH_TO_PYANNOTE + rttm_file
    #reverb_rttm_path = PATH_TO_REVERB + rttm_file

    reference_rttm_path = PATH_TO_REFERENCE + rttm_file
    
    #nemo_error = compute_der(nemo_rttm_path, reference_rttm_path)
    pyannote_error = compute_der(pyannote_rttm_path, reference_rttm_path)
    #reverb_error = compute_der(reverb_rttm_path, reference_rttm_path)

    #nemo_scores.append(nemo_error)
    pyannote_scores.append(pyannote_error)
    #reverb_scores.append(reverb_error)
    
    #print(f"For {rttm_file} : {pyannote_error}")

    count+=1
    if count % 1 == 0:
        print(f"We are at {count}!")

#print(f"Average Nemo DER score : {sum(nemo_scores)/len(nemo_scores)}")
print(f"Average Pyannote DER score : {sum(pyannote_scores)/len(pyannote_scores)}")
#print(f"Average Reverb DER score : {sum(reverb_scores)/len(reverb_scores)}")
# Out:
# TS3003b.Mix-Headset.rttm
# We are at 1!
# IB4002.Mix-Headset.rttm
# /home/digitalhub/.local/lib/python3.11/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# We are at 2!
# IS1009d.Mix-Headset.rttm
# We are at 3!
# ES2002d.Mix-Headset.rttm
# We are at 4!
# EN2001e.Mix-Headset.rttm
# We are at 5!
# ES2014a.Mix-Headset.rttm
# We are at 6!
# IS1000c.Mix-Headset.rttm
# We are at 7!
# IS1002b.Mix-Headset.rttm
# We are at 8!
# ES2008a.Mix-Headset.rttm
# We are at 9!
# IS1002d.Mix-Headset.rttm
# We are at 10!
# IN1013.Mix-Headset.rttm
# We are at 11!
# TS3006b.Mix-Headset.rttm
# We are at 12!
# IS1007b.Mix-Headset.rttm
# We are at 13!
# ES2014d.Mix-Headset.rttm
# We are at 14!
# TS3010a.Mix-Headset.rttm
# We are at 15!
# ES2005c.Mix-Headset.rttm
# We are at 16!
# IS1004d.Mix-Headset.rttm
# We are at 17!
# IB4011.Mix-Headset.rttm
# We are at 18!
# ES2016c.Mix-Headset.rttm
# We are at 19!
# TS3006c.Mix-Headset.rttm
# We are at 20!
# IS1002c.Mix-Headset.rttm
# We are at 21!
# IN1001.Mix-Headset.rttm
# We are at 22!
# IS1000b.Mix-Headset.rttm
# We are at 23!
# TS3011a.Mix-Headset.rttm
# We are at 24!
# IS1004b.Mix-Headset.rttm
# We are at 25!
# ES2010d.Mix-Headset.rttm
# We are at 26!
# ES2003d.Mix-Headset.rttm
# We are at 27!
# IN1012.Mix-Headset.rttm
# We are at 28!
# IB4003.Mix-Headset.rttm
# We are at 29!
# ES2005a.Mix-Headset.rttm
# We are at 30!
# IS1003c.Mix-Headset.rttm
# We are at 31!
# ES2014b.Mix-Headset.rttm
# We are at 32!
# ES2015c.Mix-Headset.rttm
# We are at 33!
# IS1004c.Mix-Headset.rttm
# We are at 34!
# EN2006b.Mix-Headset.rttm
# We are at 35!
# ES2009b.Mix-Headset.rttm
# We are at 36!
# TS3011b.Mix-Headset.rttm
# We are at 37!
# ES2004a.Mix-Headset.rttm
# We are at 38!
# TS3010d.Mix-Headset.rttm
# We are at 39!
# ES2008d.Mix-Headset.rttm
# We are at 40!
# ES2015a.Mix-Headset.rttm
# We are at 41!
# TS3005b.Mix-Headset.rttm
# We are at 42!
# IS1001b.Mix-Headset.rttm
# We are at 43!
# EN2005a.Mix-Headset.rttm
# We are at 44!
# IS1009a.Mix-Headset.rttm
# We are at 45!
# TS3010b.Mix-Headset.rttm
# We are at 46!
# IS1003b.Mix-Headset.rttm
# We are at 47!
# ES2006a.Mix-Headset.rttm
# We are at 48!
# IN1002.Mix-Headset.rttm
# We are at 49!
# TS3007b.Mix-Headset.rttm
# We are at 50!
# ES2011b.Mix-Headset.rttm
# We are at 51!
# ES2004d.Mix-Headset.rttm
# We are at 52!
# ES2014c.Mix-Headset.rttm
# We are at 53!
# ES2012d.Mix-Headset.rttm
# We are at 54!
# IS1001c.Mix-Headset.rttm
# We are at 55!
# ES2008b.Mix-Headset.rttm
# We are at 56!
# TS3007d.Mix-Headset.rttm
# We are at 57!
# ES2010c.Mix-Headset.rttm
# We are at 58!
# ES2012c.Mix-Headset.rttm
# We are at 59!
# IS1001d.Mix-Headset.rttm
# We are at 60!
# IN1005.Mix-Headset.rttm
# We are at 61!
# TS3012a.Mix-Headset.rttm
# We are at 62!
# TS3007a.Mix-Headset.rttm
# We are at 63!
# ES2013a.Mix-Headset.rttm
# We are at 64!
# TS3008c.Mix-Headset.rttm
# We are at 65!
# IS1008d.Mix-Headset.rttm
# We are at 66!
# TS3007c.Mix-Headset.rttm
# We are at 67!
# ES2016d.Mix-Headset.rttm
# We are at 68!
# ES2007c.Mix-Headset.rttm
# We are at 69!
# ES2004c.Mix-Headset.rttm
# We are at 70!
# IS1009c.Mix-Headset.rttm
# We are at 71!
# EN2009b.Mix-Headset.rttm
# We are at 72!
# TS3004b.Mix-Headset.rttm
# We are at 73!
# TS3011d.Mix-Headset.rttm
# We are at 74!
# TS3011c.Mix-Headset.rttm
# We are at 75!
# IB4004.Mix-Headset.rttm
# We are at 76!
# ES2009d.Mix-Headset.rttm
# We are at 77!
# EN2001a.Mix-Headset.rttm
# We are at 78!
# IS1006a.Mix-Headset.rttm
# We are at 79!
# IS1009b.Mix-Headset.rttm
# We are at 80!
# ES2012b.Mix-Headset.rttm
# We are at 81!
# IN1016.Mix-Headset.rttm
# We are at 82!
# TS3009d.Mix-Headset.rttm
# We are at 83!
# TS3009a.Mix-Headset.rttm
# We are at 84!
# EN2009d.Mix-Headset.rttm
# We are at 85!
# EN2004a.Mix-Headset.rttm
# We are at 86!
# ES2013d.Mix-Headset.rttm
# We are at 87!
# EN2003a.Mix-Headset.rttm
# We are at 88!
# ES2013c.Mix-Headset.rttm
# We are at 89!
# TS3003a.Mix-Headset.rttm
# We are at 90!
# TS3003c.Mix-Headset.rttm
# We are at 91!
# ES2016a.Mix-Headset.rttm
# We are at 92!
# IS1007a.Mix-Headset.rttm
# We are at 93!
# TS3006d.Mix-Headset.rttm
# We are at 94!
# ES2013b.Mix-Headset.rttm
# We are at 95!
# IS1004a.Mix-Headset.rttm
# We are at 96!
# ES2007a.Mix-Headset.rttm
# We are at 97!
# ES2011c.Mix-Headset.rttm
# We are at 98!
# EN2009c.Mix-Headset.rttm
# We are at 99!
# TS3004a.Mix-Headset.rttm
# We are at 100!
# ES2012a.Mix-Headset.rttm
# We are at 101!
# ES2006d.Mix-Headset.rttm
# We are at 102!
# TS3008a.Mix-Headset.rttm
# We are at 103!
# TS3012d.Mix-Headset.rttm
# We are at 104!
# IB4001.Mix-Headset.rttm
# We are at 105!
# ES2010a.Mix-Headset.rttm
# We are at 106!
# ES2003a.Mix-Headset.rttm
# We are at 107!
# IS1008a.Mix-Headset.rttm
# We are at 108!
# IS1006c.Mix-Headset.rttm
# We are at 109!
# TS3005c.Mix-Headset.rttm
# We are at 110!
# TS3012c.Mix-Headset.rttm
# We are at 111!
# EN2002b.Mix-Headset.rttm
# We are at 112!
# TS3008d.Mix-Headset.rttm
# We are at 113!
# IB4010.Mix-Headset.rttm
# We are at 114!
# ES2016b.Mix-Headset.rttm
# We are at 115!
# IN1008.Mix-Headset.rttm
# We are at 116!
# EN2001b.Mix-Headset.rttm
# We are at 117!
# IS1000a.Mix-Headset.rttm
# We are at 118!
# TS3009c.Mix-Headset.rttm
# We are at 119!
# ES2006b.Mix-Headset.rttm
# We are at 120!
# IN1009.Mix-Headset.rttm
# We are at 121!
# ES2011a.Mix-Headset.rttm
# We are at 122!
# ES2015b.Mix-Headset.rttm
# We are at 123!
# TS3005d.Mix-Headset.rttm
# We are at 124!
# IS1007c.Mix-Headset.rttm
# We are at 125!
# TS3003d.Mix-Headset.rttm
# We are at 126!
# IS1005a.Mix-Headset.rttm
# We are at 127!
# IS1003d.Mix-Headset.rttm
# We are at 128!
# ES2003b.Mix-Headset.rttm
# We are at 129!
# EN2002c.Mix-Headset.rttm
# We are at 130!
# IN1007.Mix-Headset.rttm
# We are at 131!
# IS1000d.Mix-Headset.rttm
# We are at 132!
# ES2015d.Mix-Headset.rttm
# We are at 133!
# ES2009a.Mix-Headset.rttm
# We are at 134!
# IN1014.Mix-Headset.rttm
# We are at 135!
# ES2003c.Mix-Headset.rttm
# We are at 136!
# IS1008c.Mix-Headset.rttm
# We are at 137!
# EN2006a.Mix-Headset.rttm
# We are at 138!
# ES2002c.Mix-Headset.rttm
# We are at 139!
# EN2002d.Mix-Headset.rttm
# We are at 140!
# ES2002b.Mix-Headset.rttm
# We are at 141!
# ES2002a.Mix-Headset.rttm
# We are at 142!
# IS1006b.Mix-Headset.rttm
# We are at 143!
# IS1007d.Mix-Headset.rttm
# We are at 144!
# TS3005a.Mix-Headset.rttm
# We are at 145!
# ES2005d.Mix-Headset.rttm
# We are at 146!
# TS3006a.Mix-Headset.rttm
# We are at 147!
# TS3010c.Mix-Headset.rttm
# We are at 148!
# EN2002a.Mix-Headset.rttm
# We are at 149!
# TS3009b.Mix-Headset.rttm
# We are at 150!
# ES2009c.Mix-Headset.rttm
# We are at 151!
# ES2007d.Mix-Headset.rttm
# We are at 152!
# TS3008b.Mix-Headset.rttm
# We are at 153!
# ES2005b.Mix-Headset.rttm
# We are at 154!
# IS1003a.Mix-Headset.rttm
# We are at 155!
# IS1008b.Mix-Headset.rttm
# We are at 156!
# ES2008c.Mix-Headset.rttm
# We are at 157!
# ES2004b.Mix-Headset.rttm
# We are at 158!
# ES2010b.Mix-Headset.rttm
# We are at 159!
# EN2001d.Mix-Headset.rttm
# We are at 160!
# TS3012b.Mix-Headset.rttm
# We are at 161!
# IS1001a.Mix-Headset.rttm
# We are at 162!
# ES2006c.Mix-Headset.rttm
# We are at 163!
# ES2011d.Mix-Headset.rttm
# We are at 164!
# ES2007b.Mix-Headset.rttm
# We are at 165!
# IS1005c.Mix-Headset.rttm
# We are at 166!
# IS1006d.Mix-Headset.rttm
# We are at 167!
# TS3004c.Mix-Headset.rttm
# We are at 168!
# TS3004d.Mix-Headset.rttm
# We are at 169!
# IS1005b.Mix-Headset.rttm
# We are at 170!
# Average Pyannote DER score : 0.1648839377808588

# %% [markdown]
# # tqdm for cool progress bar

# %%
import os

rttm_files_done = [f for f in os.listdir('outputs/reverb') if f.endswith(".rttm")]

PATH_TO_PYANNOTE = 'outputs/pyannote_deconstructed/'

PATH_TO_REFERENCE = 'ami_dataset/rttm/'

nemo_scores = []
pyannote_scores = []
reverb_scores = []

count = 0

for rttm_file in rttm_files_done:

    pyannote_rttm_path = PATH_TO_PYANNOTE + rttm_file

    reference_rttm_path = PATH_TO_REFERENCE + rttm_file
    
    pyannote_error = compute_der(pyannote_rttm_path, reference_rttm_path)

    pyannote_scores.append(pyannote_error)

    count+=1
    print(count)
    print(rttm_file)
    # if count % 10 == 0:
    #     print(f"We are at {count}!")

print(f"Average Pyannote Deconstructed DER score : {sum(pyannote_scores)/len(pyannote_scores)}")
# Out:
# /home/digitalhub/.local/lib/python3.11/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# 1
# TS3003b.Mix-Headset.rttm
# 2
# IB4002.Mix-Headset.rttm
# 3
# IS1009d.Mix-Headset.rttm
# 4
# ES2002d.Mix-Headset.rttm
# 5
# EN2001e.Mix-Headset.rttm
# 6
# ES2014a.Mix-Headset.rttm
# 7
# IS1000c.Mix-Headset.rttm
# 8
# IS1002b.Mix-Headset.rttm
# 9
# ES2008a.Mix-Headset.rttm
# 10
# IS1002d.Mix-Headset.rttm
# 11
# IN1013.Mix-Headset.rttm
# 12
# TS3006b.Mix-Headset.rttm
# 13
# IS1007b.Mix-Headset.rttm
# 14
# ES2014d.Mix-Headset.rttm
# 15
# TS3010a.Mix-Headset.rttm
# 16
# ES2005c.Mix-Headset.rttm
# 17
# IS1004d.Mix-Headset.rttm
# 18
# IB4011.Mix-Headset.rttm
# 19
# ES2016c.Mix-Headset.rttm
# 20
# TS3006c.Mix-Headset.rttm
# 21
# IS1002c.Mix-Headset.rttm
# 22
# IN1001.Mix-Headset.rttm
# 23
# IS1000b.Mix-Headset.rttm
# 24
# TS3011a.Mix-Headset.rttm
# 25
# IS1004b.Mix-Headset.rttm
# 26
# ES2010d.Mix-Headset.rttm
# 27
# ES2003d.Mix-Headset.rttm
# 28
# IN1012.Mix-Headset.rttm
# 29
# IB4003.Mix-Headset.rttm
# 30
# ES2005a.Mix-Headset.rttm
# 31
# IS1003c.Mix-Headset.rttm
# 32
# ES2014b.Mix-Headset.rttm
# 33
# ES2015c.Mix-Headset.rttm
# 34
# IS1004c.Mix-Headset.rttm
# 35
# EN2006b.Mix-Headset.rttm
# 36
# ES2009b.Mix-Headset.rttm
# 37
# TS3011b.Mix-Headset.rttm
# 38
# ES2004a.Mix-Headset.rttm
# 39
# TS3010d.Mix-Headset.rttm
# 40
# ES2008d.Mix-Headset.rttm
# 41
# ES2015a.Mix-Headset.rttm
# 42
# TS3005b.Mix-Headset.rttm
# 43
# IS1001b.Mix-Headset.rttm
# 44
# EN2005a.Mix-Headset.rttm
# 45
# IS1009a.Mix-Headset.rttm
# 46
# TS3010b.Mix-Headset.rttm
# 47
# IS1003b.Mix-Headset.rttm
# 48
# ES2006a.Mix-Headset.rttm
# 49
# IN1002.Mix-Headset.rttm
# 50
# TS3007b.Mix-Headset.rttm
# 51
# ES2011b.Mix-Headset.rttm
# 52
# ES2004d.Mix-Headset.rttm
# 53
# ES2014c.Mix-Headset.rttm
# 54
# ES2012d.Mix-Headset.rttm
# 55
# IS1001c.Mix-Headset.rttm
# 56
# ES2008b.Mix-Headset.rttm
# 57
# TS3007d.Mix-Headset.rttm
# 58
# ES2010c.Mix-Headset.rttm
# 59
# ES2012c.Mix-Headset.rttm
# 60
# IS1001d.Mix-Headset.rttm
# 61
# IN1005.Mix-Headset.rttm
# 62
# TS3012a.Mix-Headset.rttm
# 63
# TS3007a.Mix-Headset.rttm
# 64
# ES2013a.Mix-Headset.rttm
# 65
# TS3008c.Mix-Headset.rttm
# 66
# IS1008d.Mix-Headset.rttm
# 67
# TS3007c.Mix-Headset.rttm
# 68
# ES2016d.Mix-Headset.rttm
# 69
# ES2007c.Mix-Headset.rttm
# 70
# ES2004c.Mix-Headset.rttm
# 71
# IS1009c.Mix-Headset.rttm
# 72
# EN2009b.Mix-Headset.rttm
# 73
# TS3004b.Mix-Headset.rttm
# 74
# TS3011d.Mix-Headset.rttm
# 75
# TS3011c.Mix-Headset.rttm
# 76
# IB4004.Mix-Headset.rttm
# 77
# ES2009d.Mix-Headset.rttm
# 78
# EN2001a.Mix-Headset.rttm
# 79
# IS1006a.Mix-Headset.rttm
# 80
# IS1009b.Mix-Headset.rttm
# 81
# ES2012b.Mix-Headset.rttm
# 82
# IN1016.Mix-Headset.rttm
# 83
# TS3009d.Mix-Headset.rttm
# 84
# TS3009a.Mix-Headset.rttm
# 85
# EN2009d.Mix-Headset.rttm
# 86
# EN2004a.Mix-Headset.rttm
# 87
# ES2013d.Mix-Headset.rttm
# 88
# EN2003a.Mix-Headset.rttm
# 89
# ES2013c.Mix-Headset.rttm
# 90
# TS3003a.Mix-Headset.rttm
# 91
# TS3003c.Mix-Headset.rttm
# 92
# ES2016a.Mix-Headset.rttm
# 93
# IS1007a.Mix-Headset.rttm
# 94
# TS3006d.Mix-Headset.rttm
# 95
# ES2013b.Mix-Headset.rttm
# 96
# IS1004a.Mix-Headset.rttm
# 97
# ES2007a.Mix-Headset.rttm
# 98
# ES2011c.Mix-Headset.rttm
# 99
# EN2009c.Mix-Headset.rttm
# 100
# TS3004a.Mix-Headset.rttm
# 101
# ES2012a.Mix-Headset.rttm
# 102
# ES2006d.Mix-Headset.rttm
# 103
# TS3008a.Mix-Headset.rttm
# 104
# TS3012d.Mix-Headset.rttm
# 105
# IB4001.Mix-Headset.rttm
# 106
# ES2010a.Mix-Headset.rttm
# 107
# ES2003a.Mix-Headset.rttm
# 108
# IS1008a.Mix-Headset.rttm
# 109
# IS1006c.Mix-Headset.rttm
# 110
# TS3005c.Mix-Headset.rttm
# 111
# TS3012c.Mix-Headset.rttm
# 112
# EN2002b.Mix-Headset.rttm
# 113
# TS3008d.Mix-Headset.rttm
# 114
# IB4010.Mix-Headset.rttm
# 115
# ES2016b.Mix-Headset.rttm
# 116
# IN1008.Mix-Headset.rttm
# 117
# EN2001b.Mix-Headset.rttm
# 118
# IS1000a.Mix-Headset.rttm
# 119
# TS3009c.Mix-Headset.rttm
# 120
# ES2006b.Mix-Headset.rttm
# 121
# IN1009.Mix-Headset.rttm
# 122
# ES2011a.Mix-Headset.rttm
# 123
# ES2015b.Mix-Headset.rttm
# 124
# TS3005d.Mix-Headset.rttm
# 125
# IS1007c.Mix-Headset.rttm
# 126
# TS3003d.Mix-Headset.rttm
# 127
# IS1005a.Mix-Headset.rttm
# 128
# IS1003d.Mix-Headset.rttm
# 129
# ES2003b.Mix-Headset.rttm
# 130
# EN2002c.Mix-Headset.rttm
# 131
# IN1007.Mix-Headset.rttm
# 132
# IS1000d.Mix-Headset.rttm
# 133
# ES2015d.Mix-Headset.rttm
# 134
# ES2009a.Mix-Headset.rttm
# 135
# IN1014.Mix-Headset.rttm
# 136
# ES2003c.Mix-Headset.rttm
# 137
# IS1008c.Mix-Headset.rttm
# 138
# EN2006a.Mix-Headset.rttm
# 139
# ES2002c.Mix-Headset.rttm
# 140
# EN2002d.Mix-Headset.rttm
# 141
# ES2002b.Mix-Headset.rttm
# 142
# ES2002a.Mix-Headset.rttm
# 143
# IS1006b.Mix-Headset.rttm
# 144
# IS1007d.Mix-Headset.rttm
# 145
# TS3005a.Mix-Headset.rttm
# 146
# ES2005d.Mix-Headset.rttm
# 147
# TS3006a.Mix-Headset.rttm
# 148
# TS3010c.Mix-Headset.rttm
# 149
# EN2002a.Mix-Headset.rttm
# 150
# TS3009b.Mix-Headset.rttm
# 151
# ES2009c.Mix-Headset.rttm
# 152
# ES2007d.Mix-Headset.rttm
# 153
# TS3008b.Mix-Headset.rttm
# 154
# ES2005b.Mix-Headset.rttm
# 155
# IS1003a.Mix-Headset.rttm
# 156
# IS1008b.Mix-Headset.rttm
# 157
# ES2008c.Mix-Headset.rttm
# 158
# ES2004b.Mix-Headset.rttm
# 159
# ES2010b.Mix-Headset.rttm
# 160
# EN2001d.Mix-Headset.rttm
# 161
# TS3012b.Mix-Headset.rttm
# 162
# IS1001a.Mix-Headset.rttm
# 163
# ES2006c.Mix-Headset.rttm
# 164
# ES2011d.Mix-Headset.rttm
# 165
# ES2007b.Mix-Headset.rttm
# 166
# IS1005c.Mix-Headset.rttm
# 167
# IS1006d.Mix-Headset.rttm
# 168
# TS3004c.Mix-Headset.rttm
# 169
# TS3004d.Mix-Headset.rttm
# 170
# IS1005b.Mix-Headset.rttm
# Average Pyannote Deconstructed DER score : 0.4675652616690118

# %%
path_1 = "2_speaker_fake_diar.rttm"
path_2 = "hyp_full_155_spk.rttm"
path_ref = "2_speaker_001.rttm"

compute_der(path_1, path_ref)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 path_2 = "hyp_full_155_spk.rttm"
#       3 path_ref = "2_speaker_001.rttm"
# ----> 5 compute_der(path_1, path_ref)
#
# Cell In[3], line 30, in compute_der(hyp_rttm_path, ref_rttm_path)
#      22 """
#      23 Compute Diarization Error Rate (DER) allowing overlap.
#      24
#    (...)
#      27 :return: DER score
#      28 """
#      29 metric = DiarizationErrorRate(skip_overlap=False)
# ---> 30 hypothesis = read_rttm_file_into_annotation(hyp_rttm_path)
#      31 reference = read_rttm_file_into_annotation(ref_rttm_path)
#      33 der_score = metric(reference, hypothesis)
#
# Cell In[3], line 8, in read_rttm_file_into_annotation(rttm_path)
#       4 def read_rttm_file_into_annotation(rttm_path):
#       6     speaker_segments = Annotation()
# ----> 8     with open(rttm_path, 'r') as f:
#       9         for line in f:
#      10             parts = line.strip().split()
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '2_speaker_fake_diar.rttm'

# %%
compute_der(path_2, path_ref)
# Out:
# 0.6114500788362726

# %%
def read_rttm_file_into_annotation(rttm_path):

    speaker_segments = Annotation()
    
    with open(rttm_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if parts[0] == "SPEAKER": 
                speaker = parts[7]
                print(speaker)
                start_time = float(parts[3])
                duration = float(parts[4])
                end_time = start_time + duration

                speaker_segments[Segment(round(start_time, 2), round(end_time,2))] = speaker

    return speaker_segments

# %%
def load_rttm(path):
    ref = Annotation(uri="EN2001a.Mix-Headset")
    with open(path) as f:
        for line in f:
            _, uri, _, start, dur, _ , _ , spk, *_ = line.strip().split()
            start, dur = float(start), float(dur)
            ref[Segment(start, start + dur)] = spk
    return ref

# %%
path = 'testing.rttm'

test1 = read_rttm_file_into_annotation(path)
test2 = load_rttm(path)
# Out:
# speaker_0
# speaker_0
# speaker_0
# speaker_4
# speaker_4
# speaker_0
# speaker_0
# speaker_0
# speaker_4
# speaker_4

# %%
from pyannote.database.util import load_rttm

reference = load_rttm(path_ref)
hyp = load_rttm(path_1)

reference_annotation = list(reference.values())[0]
hyp_annotation = list(hyp.values())[0]

metric = DiarizationErrorRate(collar=0.0, skip_overlap=False)
der = metric(reference_annotation, hyp_annotation, detailed=True)

der
# Out:
# /home/digitalhub/.local/lib/python3.11/site-packages/pyannote/metrics/utils.py:200: UserWarning: 'uem' was approximated by the union of 'reference' and 'hypothesis' extents.
#   warnings.warn(
# {'missed detection': 189.49500000000225,
#  'confusion': 660.2119999999904,
#  'correct': 4065.5429999999933,
#  'false alarm': 106.13200000000413,
#  'total': 4915.249999999986,
#  'diarization error rate': 0.1944639641930725}

# %%
from pyannote.database.util import load_rttm

reference = load_rttm(path_ref)
hyp = load_rttm(path_2)

reference_annotation = list(reference.values())[0]
hyp_annotation = list(hyp.values())[0]

metric = DiarizationErrorRate(collar=0.0, skip_overlap=False)
der = metric(reference_annotation, hyp_annotation, detailed=True)

der
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pyannote.database.util import load_rttm
# ----> 3 reference = load_rttm(path_ref)
#       4 hyp = load_rttm(path_2)
#       6 reference_annotation = list(reference.values())[0]
#
# NameError: name 'path_ref' is not defined
